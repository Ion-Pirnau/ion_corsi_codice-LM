# %%
import pandas as pd

# %%
data = [
    {"name": "Alice", "age": 30, "city": "New York"},
    {"name": "Bob", "age": 25, "city": "Paris"},
    {"name": "Charlie", "age": 35, "city": "London"}
]

df = pd.DataFrame(data)
print(df)
# Out:
#       name  age      city
# 0    Alice   30  New York
# 1      Bob   25     Paris
# 2  Charlie   35    London

# %%
grouped = df.groupby("city")
avg_age_by_city = grouped["age"].mean()
print(avg_age_by_city)
# Out:
# city
# London      35.0
# New York    30.0
# Paris       25.0
# Name: age, dtype: float64

# %%
from sklearn.datasets import load_iris

iris = load_iris()

df_iris = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df_iris['target'] = pd.Series(iris.target)

df_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
df.dtypes
# Out:
# sepal length (cm)    float64
# sepal width (cm)     float64
# petal length (cm)    float64
# petal width (cm)     float64
# target                 int64
# dtype: object

# %%
import sklearn as sk
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../Dataset/decathlon.csv")

df.head()
# Out:
#    Athlets       "100m"    "Long.jump"   "Shot.put"   "High.jump"   "400m"   \
# 0  SEBRLE        "11.04"   "7.58"        "14.83"      "2.07"        "49.81"
# 1  CLAY          "10.76"   "7.4"         "14.26"      "1.86"        "49.37"
# 2  KARPOV        "11.02"   "7.3"         "14.77"      "2.04"        "48.37"
# 3  BERNARD       "11.02"   "7.23"        "14.25"      "1.92"        "48.93"
# 4  YURKOV        "11.34"   "7.09"        "15.19"      "2.1"         "50.42"
#
#     "110m.hurdle"   "Discus"   "Pole.vault"   "Javeline"   "1500m"    "Rank"  \
# 0   "14.69"         "43.75"    "5.02"         "63.19"      "291.7"    "1"
# 1   "14.05"         "50.72"    "4.92"         "60.15"      "301.5"    "2"
# 2   "14.09"         "48.95"    "4.92"         "50.31"      "300.2"    "3"
# 3   "14.99"         "40.87"    "5.32"         "62.77"      "280.1"    "4"
# 4   "15.31"         "46.26"    "4.72"         "63.44"      "276.4"    "5"
#
#     "Points"  "Competition"
# 0   "8217"       "Decastar"
# ...

# %%
df.dtypes
# Out:
# Athlets           object
#  "100m"           object
#  "Long.jump"      object
#  "Shot.put"       object
#  "High.jump"      object
#  "400m"           object
#  "110m.hurdle"    object
#  "Discus"         object
#  "Pole.vault"     object
#  "Javeline"       object
#  "1500m"          object
#  "Rank"           object
#  "Points"         object
#  "Competition"    object
# dtype: object

# %%
df.describe()
# Out:
#         Athlets       "100m"    "Long.jump"   "Shot.put"   "High.jump"  \
# count            41        41            41           41            41
# unique           41        33            33           38            19
# top     SEBRLE        "11.33"   "7.3"         "14.26"      "1.94"
# freq              1         3             3            2             8
#
#          "400m"    "110m.hurdle"   "Discus"   "Pole.vault"   "Javeline"  \
# count         41              41         41             41           41
# unique        40              36         39             18           41
# top      "51.16"   "14.01"         "44.41"    "4.92"         "63.19"
# freq           2               3          2              4            1
#
#          "1500m"    "Rank"   "Points"  "Competition"
# count          41       41         41             41
# unique         38       28         39              2
# top      "291.7"    "1"      "8067"       "OlympicG"
# ...

# %%
df.select_dtypes(["object"]).describe()
# Out:
#         Athlets       "100m"    "Long.jump"   "Shot.put"   "High.jump"  \
# count            41        41            41           41            41
# unique           41        33            33           38            19
# top     SEBRLE        "11.33"   "7.3"         "14.26"      "1.94"
# freq              1         3             3            2             8
#
#          "400m"    "110m.hurdle"   "Discus"   "Pole.vault"   "Javeline"  \
# count         41              41         41             41           41
# unique        40              36         39             18           41
# top      "51.16"   "14.01"         "44.41"    "4.92"         "63.19"
# freq           2               3          2              4            1
#
#          "1500m"    "Rank"   "Points"  "Competition"
# count          41       41         41             41
# unique         38       28         39              2
# top      "291.7"    "1"      "8067"       "OlympicG"
# ...

# %%
variabili_numeriche = list(df.columns[1:-1])
print(variabili_numeriche)
# Out:
# [' "100m" ', ' "Long.jump"', ' "Shot.put"', ' "High.jump"', ' "400m" ', ' "110m.hurdle"', ' "Discus"', ' "Pole.vault"', ' "Javeline"', ' "1500m" ', ' "Rank"', ' "Points"']

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

#df_n = pd.to_numeric(df[variabili_numeriche])
lista_val = df[variabili_numeriche].values.tolist()
lista_pulita = [[val.strip().replace('"', '') for val in sublist] for sublist in lista_val]
lista_pulita

df_n = pd.DataFrame(lista_pulita)
#df_n

scaled_data = scaler.fit_transform(df_n)
scaled_data
# Out:
# array([[ 1.61477791e-01,  1.02393687e+00,  4.33405055e-01,
#          1.06045671e+00,  1.69980655e-01,  1.80571557e-01,
#         -1.72524347e-01,  9.37988410e-01,  1.02219600e+00,
#          1.09931561e+00, -1.42192065e+00,  6.25795966e-01],
#        [-9.16292580e-01,  4.47972380e-01, -2.66572563e-01,
#         -1.32973498e+00, -2.16222244e-01, -1.19281907e+00,
#          1.91655543e+00,  5.73807304e-01,  3.84557695e-01,
#          1.94927138e+00, -1.29407253e+00,  3.44883751e-01],
#        [ 8.44941928e-02,  1.27992108e-01,  3.59723200e-01,
#          7.19000754e-01, -1.09395610e+00, -1.10698215e+00,
#          1.38604306e+00,  5.73807304e-01, -1.67937681e+00,
#          1.83652215e+00, -1.16622440e+00,  2.76873425e-01],
#        [ 8.44941928e-02, -9.59940813e-02, -2.78852872e-01,
#         -6.46823072e-01, -6.02425143e-01,  8.24348413e-01,
#         -1.03573091e+00,  2.03053173e+00,  9.34101232e-01,
#          9.32455207e-02, -1.03837627e+00,  1.82250364e-01],
# ...

# %%
import matplotlib.pyplot as plt

pca = PCA().fit(scaled_data)

plt.plot(range(1, pca.n_components_ + 1), pca.explained_variance_ratio_, marker='o')
plt.xlabel('Componenti della PCA')
plt.ylabel('Varianza speigata')
plt.title('Risultati della PCA')
plt.show()

# %%
pca = PCA(n_components=2).fit(scaled_data)
pca_data = pca.transform(scaled_data)

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.39656587 0.14501218]

# %%
df[' "Competition"']
# Out:
# 0      "Decastar"
# 1      "Decastar"
# 2      "Decastar"
# 3      "Decastar"
# 4      "Decastar"
# 5      "Decastar"
# 6      "Decastar"
# 7      "Decastar"
# 8      "Decastar"
# 9      "Decastar"
# 10     "Decastar"
# 11     "Decastar"
# 12     "Decastar"
# 13     "OlympicG"
# 14     "OlympicG"
# 15     "OlympicG"
# 16     "OlympicG"
# 17     "OlympicG"
# 18     "OlympicG"
# 19     "OlympicG"
# 20     "OlympicG"
# 21     "OlympicG"
# 22     "OlympicG"
# 23     "OlympicG"
# 24     "OlympicG"
# 25     "OlympicG"
# 26     "OlympicG"
# 27     "OlympicG"
# 28     "OlympicG"
# 29     "OlympicG"
# 30     "OlympicG"
# 31     "OlympicG"
# 32     "OlympicG"
# 33     "OlympicG"
# 34     "OlympicG"
# 35     "OlympicG"
# 36     "OlympicG"
# 37     "OlympicG"
# 38     "OlympicG"
# 39     "OlympicG"
# 40     "OlympicG"
# Name:  "Competition", dtype: object

# %%
unique_labels = np.unique(df[' "Competition"'])
lista_unique_labels = [val.strip().replace('"', '') for val in unique_labels]

lista = df[' "Competition"'].tolist()

lista_competition = [val.strip().replace('"', '') for val in lista]
print(lista_competition)
print(unique_labels)
print((df[' "Competition"'] == ' "Decastar"').values)
# Out:
# ['Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'Decastar', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG', 'OlympicG']
# [' "Decastar"' ' "OlympicG"']
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False]

# %%
colors = plt.cm.tab20(np.linspace(0, 1, len(lista_unique_labels)))
label_to_color = dict(zip(lista_unique_labels, colors))
print(label_to_color)

fig, ax = plt.subplots()
mask = (df[' "Competition"'] == ' "Decastar"').values
ax.scatter(pca_data[mask, 0], pca_data[mask, 1], color=label_to_color['Decastar'], label='Decastar')
    
mask = (df[' "Competition"'] == ' "OlympicG"').values
ax.scatter(pca_data[mask, 0], pca_data[mask, 1], color=label_to_color['OlympicG'], label='OlympicG')


ax.set_xlabel('Componente 1')
ax.set_ylabel('Componente 2')

ax.legend()

plt.show()
# Out:
# {'Decastar': array([0.12156863, 0.46666667, 0.70588235, 1.        ]), 'OlympicG': array([0.61960784, 0.85490196, 0.89803922, 1.        ])}

# %%
print(abs(pca.components_))
# Out:
# [[0.32462717 0.34651451 0.28038448 0.26949298 0.31872084 0.3224588
#   0.24267251 0.06639577 0.14621541 0.04809361 0.35809724 0.45001821]
#  [0.11949296 0.25237393 0.46413427 0.27269463 0.42042142 0.15540646
#   0.46898486 0.1528422  0.24403309 0.35562852 0.04480845 0.00118215]]

# %%
ax = sns.heatmap(pca.components_,
                 cmap='YlGnBu',
                 yticklabels=[ "PCA"+str(x) for x in range(1, pca.n_components_+1)],
                 xticklabels=list(variabili_numeriche),
                 cbar_kws={"orientation": "vertical"})

ax.set_aspect("equal")

# %%
loadings = pca.components_
num_pc = pca.n_features_in_
pc_list = ["PC"+str(i) for i in list(range(1, num_pc+1))]
loadings_df = pd.DataFrame.from_dict(dict(zip(pc_list, loadings)))
loadings_df

loadings_df['variable'] = variabili_numeriche
loadings_df = loadings_df.set_index('variable')
loadings_df

ax = sns.heatmap(loadings_df, annot=True, cmap='Spectral')
plt.show()

# %%
pcs = pca.components_
fig = plt.figure(figsize=(6,5))
ax = fig.add_subplot(1, 1, 1)
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])

for i, (x,y) in enumerate(zip(pcs[0, :], pcs[1, :])):
    ax.plot([0, x], [0, y], color='g')
    ax.text(x, y, df.columns[i], fontsize='15')

# %%
df_iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
var_num_iris = list(df_iris.columns[0:-1])
print(var_num_iris)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df_iris[var_num_iris])
scaled_data
# Out:
# array([[-9.00681170e-01,  1.01900435e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00, -1.31979479e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.38535265e+00,  3.28414053e-01, -1.39706395e+00,
#         -1.31544430e+00],
#        [-1.50652052e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.02184904e+00,  1.24920112e+00, -1.34022653e+00,
#         -1.31544430e+00],
#        [-5.37177559e-01,  1.93979142e+00, -1.16971425e+00,
#         -1.05217993e+00],
#        [-1.50652052e+00,  7.88807586e-01, -1.34022653e+00,
#         -1.18381211e+00],
#        [-1.02184904e+00,  7.88807586e-01, -1.28338910e+00,
#         -1.31544430e+00],
#        [-1.74885626e+00, -3.62176246e-01, -1.34022653e+00,
#         -1.31544430e+00],
#        [-1.14301691e+00,  9.82172869e-02, -1.28338910e+00,
#         -1.44707648e+00],
#        [-5.37177559e-01,  1.47939788e+00, -1.28338910e+00,
#         -1.31544430e+00],
# ...

# %%
pca = PCA().fit(scaled_data)

# Crea un grafico della varianza spiegata per ogni componente
plt.plot(range(1, pca.n_components_ + 1), pca.explained_variance_ratio_, marker='o')
plt.xlabel('Componenti della PCA')
plt.ylabel('Varianza spiegata')
plt.title("Risultati della PCA")
plt.show()

# %%
pca = PCA(n_components=2).fit(scaled_data)
pca_data = pca.transform(scaled_data)
print(pca.explained_variance_ratio_)

eigenvalues = pca.explained_variance_
n_samples = scaled_data.shape[0]
cov_matrix = np.dot(scaled_data.T, scaled_data) / n_samples
for eigenvalue, eigenvector in zip(eigenvalues, pca.components_):
    print(np.dot(eigenvector.T, np.dot(cov_matrix, eigenvector)))
    print(eigenvalue)
# Out:
# [0.72962445 0.22850762]
# 2.918497816531998
# 2.9380850501999958
# 0.9140304714680718
# 0.9201649041624874

# %%
unique_labels = np.unique(df_iris["target"])
colors = plt.cm.tab20(np.linspace(0, 1, len(unique_labels)))
label_to_color = dict(zip(unique_labels, colors))

# genera il grafico
fig, ax = plt.subplots()
for label in unique_labels:
    mask = (df_iris["target"] == label).values
    ax.scatter(pca_data[mask, 0], pca_data[mask, 1], color=label_to_color[label], label=label)

ax.set_xlabel('Componente 1')
ax.set_ylabel('Componente 2')

ax.legend()

plt.show()

# %%
print(abs(pca.components_))
# Out:
# [[0.52106591 0.26934744 0.5804131  0.56485654]
#  [0.37741762 0.92329566 0.02449161 0.06694199]]

# %%
loadings = pca.components_
num_pc = pca.n_features_in_
pc_list = ["PC"+str(i) for i in list(range(1, num_pc+1))]
loadings_df = pd.DataFrame.from_dict(dict(zip(pc_list, loadings)))
loadings_df
loadings_df['variable'] = var_num_iris
loadings_df = loadings_df.set_index('variable')
loadings_df
import matplotlib.pyplot as plt
ax = sns.heatmap(loadings_df, annot=True, cmap='Spectral')
plt.show()

# %% [markdown]
# Risposta
# - sono necessarie solo 2 componenti per spiegare almento il 95% della varianza nei dati. (Per iris)
#
# - I dati sono separabili rispetto alle classi:
# (iris) No, classi diverse (target) prensentano punti che si sovrappongono, PCA non ha migliorato la separabilità e potrebbe non essere la tecnica migliore per distinguere le classi.
# (dataset: decathlon) Si, punti di classi diverse (Competition) non si sovrappongono, PCA ha evidenziato strutture nei dati che rendono la classificazione più semplice.
